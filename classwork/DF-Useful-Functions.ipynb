# %%
import pandas as pd
df1 = pd.read_csv('C:/Users/Ahmed Zaki/Downloads/EDA Usman/zomato.csv', encoding='latin-1')

# %%
df1['City'].value_counts()
# Out:
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: City, Length: 141, dtype: int64

# %%
df1.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df1.isnull()
# Out:
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0             False            False         False  False    False     False
# 1             False            False         False  False    False     False
# 2             False            False         False  False    False     False
# 3             False            False         False  False    False     False
# 4             False            False         False  False    False     False
# ...             ...              ...           ...    ...      ...       ...
# 9546          False            False         False  False    False     False
# 9547          False            False         False  False    False     False
# 9548          False            False         False  False    False     False
# 9549          False            False         False  False    False     False
# 9550          False            False         False  False    False     False
#
# ...

# %%
df1.isnull().any()
# Out:
# Restaurant ID           False
# Restaurant Name         False
# Country Code            False
# City                    False
# Address                 False
# Locality                False
# Locality Verbose        False
# Longitude               False
# Latitude                False
# Cuisines                 True
# Average Cost for two    False
# Currency                False
# Has Table booking       False
# Has Online delivery     False
# Is delivering now       False
# Switch to order menu    False
# Price range             False
# Aggregate rating        False
# Rating color            False
# Rating text             False
# Votes                   False
# dtype: bool

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df1['Votes'].idxmax()
df1.iloc[df1['Votes'].idxmax()]
# Out:
# Restaurant ID                                                       51705
# Restaurant Name                                                      Toit
# Country Code                                                            1
# City                                                            Bangalore
# Address                 298, Namma Metro Pillar 62, 100 Feet Road, Ind...
# Locality                                                      Indiranagar
# Locality Verbose                                   Indiranagar, Bangalore
# Longitude                                                       77.640709
# Latitude                                                        12.979166
# Cuisines                                         Italian, American, Pizza
# Average Cost for two                                                 2000
# Currency                                               Indian Rupees(Rs.)
# Has Table booking                                                      No
# ...

# %%
concatdf1=df1[['Restaurant Name', 'Country Code']]
concatdf2=df1[['Address', 'Locality']]
pd.concat([concatdf1, concatdf2], axis=0)
# Out:
#              Restaurant Name  Country Code  \
# 0           Le Petit Souffle         162.0
# 1           Izakaya Kikufuji         162.0
# 2     Heat - Edsa Shangri-La         162.0
# 3                       Ooma         162.0
# 4                Sambo Kojin         162.0
# ...                      ...           ...
# 9546                     NaN           NaN
# 9547                     NaN           NaN
# 9548                     NaN           NaN
# 9549                     NaN           NaN
# 9550                     NaN           NaN
#
#                                                 Address     Locality
# 0                                                   NaN          NaN
# 1                                                   NaN          NaN
# 2                                                   NaN          NaN
# 3                                                   NaN          NaN
# 4                                                   NaN          NaN
# ...

# %%
pd.concat([concatdf1, concatdf2], axis=1)
# Out:
#                Restaurant Name  Country Code  \
# 0             Le Petit Souffle           162
# 1             Izakaya Kikufuji           162
# 2       Heat - Edsa Shangri-La           162
# 3                         Ooma           162
# 4                  Sambo Kojin           162
# ...                        ...           ...
# 9546              NamlÛ± Gurme           208
# 9547             Ceviz AÛôacÛ±           208
# 9548                     Huqqa           208
# 9549              Aôôk Kahve           208
# 9550  Walter's Coffee Roastery           208
#
#                                                 Address  \
# 0     Third Floor, Century City Mall, Kalayaan Avenu...
# 1     Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2     Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3     Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4     Third Floor, Mega Atrium, SM Megamall, Ortigas...
# ...                                                 ...
# ...

# %%
df1.transpose
# Out:
# <bound method DataFrame.transpose of       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
# ...

# %%
df1.sort_values(by='Votes')
# Out:
#       Restaurant ID             Restaurant Name  Country Code       City  \
# 5799       18460302         Khalsa Eating Point             1  New Delhi
# 7411       18431145   Radha Swami Chaat Bhandar             1  New Delhi
# 7414       18430905  Ram Ram Ji Kachori Bhandar             1  New Delhi
# 7415       18430907          Rana's Food Corner             1  New Delhi
# 7416       18451597         Sanjay Chicken Shop             1  New Delhi
# ...             ...                         ...           ...        ...
# 739           56618   AB's - Absolute Barbecues             1  Bangalore
# 2412          20404                   Peter Cat             1    Kolkata
# 3994         308322            Hauz Khas Social             1  New Delhi
# 735           51040                    Truffles             1  Bangalore
# 728           51705                        Toit             1  Bangalore
#
#                                                 Address  \
# ...

# %%
df1.sort_values(by='Votes', ascending=False)
# Out:
#       Restaurant ID            Restaurant Name  Country Code       City  \
# 728           51705                       Toit             1  Bangalore
# 735           51040                   Truffles             1  Bangalore
# 3994         308322           Hauz Khas Social             1  New Delhi
# 2412          20404                  Peter Cat             1    Kolkata
# 739           56618  AB's - Absolute Barbecues             1  Bangalore
# ...             ...                        ...           ...        ...
# 1016       18446428                KitchenYard             1  Faridabad
# 1015       18480389                  Fritrolla             1  Faridabad
# 7836       18499493                    Zombiez             1  New Delhi
# 7835       18424192       Zaika Chicken Corner             1  New Delhi
# 4524       18458655    Singh Chinese Fast Food             1  New Delhi
#
#                                                 Address  \
# ...

# %%
df1.sort_values(by=['Votes', 'City'], ascending=False)
# Out:
#       Restaurant ID            Restaurant Name  Country Code       City  \
# 728           51705                       Toit             1  Bangalore
# 735           51040                   Truffles             1  Bangalore
# 3994         308322           Hauz Khas Social             1  New Delhi
# 2412          20404                  Peter Cat             1    Kolkata
# 739           56618  AB's - Absolute Barbecues             1  Bangalore
# ...             ...                        ...           ...        ...
# 1104           8037    Bikaner Sweets & Bakers             1  Faridabad
# 1105       18471308              Burger Xpress             1  Faridabad
# 1106       18471318              Da Pizza Zone             1  Faridabad
# 1107       18471320             Finger Licious             1  Faridabad
# 1110           9496             Shankar Sweets             1  Faridabad
#
#                                                 Address  \
# ...

# %%
df1.sort_values(by=['Votes', 'City'], ascending=[False, False])
# Out:
#       Restaurant ID            Restaurant Name  Country Code       City  \
# 728           51705                       Toit             1  Bangalore
# 735           51040                   Truffles             1  Bangalore
# 3994         308322           Hauz Khas Social             1  New Delhi
# 2412          20404                  Peter Cat             1    Kolkata
# 739           56618  AB's - Absolute Barbecues             1  Bangalore
# ...             ...                        ...           ...        ...
# 1104           8037    Bikaner Sweets & Bakers             1  Faridabad
# 1105       18471308              Burger Xpress             1  Faridabad
# 1106       18471318              Da Pizza Zone             1  Faridabad
# 1107       18471320             Finger Licious             1  Faridabad
# 1110           9496             Shankar Sweets             1  Faridabad
#
#                                                 Address  \
# ...

# %%
df1.pivot(index='Restaurant ID', columns='Votes')
# Out:
#                      Restaurant Name                                         \
# Votes                          0            1     2             3     4
# Restaurant ID
# 53                               NaN          NaN   NaN           NaN   NaN
# 55                               NaN          NaN   NaN           NaN   NaN
# 60                               NaN          NaN   NaN           NaN   NaN
# 64                               NaN          NaN   NaN           NaN   NaN
# 65                               NaN          NaN   NaN           NaN   NaN
# ...                              ...          ...   ...           ...   ...
# 18499493                     Zombiez          NaN   NaN           NaN   NaN
# 18500618                         NaN  Veg. Darbar   NaN           NaN   NaN
# 18500628                         NaN          NaN   NaN  Grill & Cafe   NaN
# 18500639       Chandni Chowk 2 China          NaN   NaN           NaN   NaN
# ...

# %%
df1.plot.bar(x='Aggregate rating',y='Country Code')
# Out:
# <AxesSubplot:xlabel='Aggregate rating'>

# %%
df1['Votes'].plot()
# Out:
# <AxesSubplot:>
