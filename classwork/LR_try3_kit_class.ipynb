# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_excel('LR_try3_kit_class.xlsx')

# %%
df.head()
# Out:
#    x(year)  y(sales)
# 0     2005        12
# 1     2006        19
# 2     2007        29
# 3     2008        37
# 4     2009        45

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   x(year)   5 non-null      int64
#  1   y(sales)  5 non-null      int64
# dtypes: int64(2)
# memory usage: 208.0 bytes

# %%
plt.scatter(df['x(year)'] , df['y(sales)'])
plt.xlabel('x')
plt.ylabel("y")
plt.title("Year vs Sales")
# Out:
# Text(0.5, 1.0, 'x vs y')

# %%
X = df.iloc[0:5 , 0].values.reshape(-1,1)
Y = df.iloc[:,-1]

# %%
from sklearn.linear_model import LinearRegression
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
lr = LinearRegression().fit(X,Y)

# %%
print("Intercept:" , lr.intercept_)
print("Slope:",lr.coef_)
# Out:
# Intercept: -16830.399999999998
# Slope: [8.4]

# %%
reg_line=lr.coef_*X+lr.intercept_
plt.figure(figsize=(12,10))
plt.title("Year vs Sales",fontsize=20,color="Blue")
plt.scatter(X,Y,label="Model",color='red')
plt.plot(X,reg_line,label="Linear Regression",color="green")

# %%
y = lr.coef_*(2023)+lr.intercept_
y
# Out:
# array([162.8])
