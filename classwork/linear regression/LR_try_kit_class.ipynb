# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df= pd.read_excel('LR_try_kit_class.xlsx')

# %%
df.head()
# Out:
#    x  y
# 0 -3 -2
# 1  0  0
# 2  3  2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       3 non-null      int64
#  1   y       3 non-null      int64
# dtypes: int64(2)
# memory usage: 176.0 bytes

# %%
plt.scatter(df['x'] , df['y'])
plt.xlabel('x')
plt.ylabel("y")
plt.title("x vs y")
# Out:
# Text(0.5, 1.0, 'x vs y')

# %%
X = df.iloc[0:3 , 0].values.reshape(-1,1)
Y = df.iloc[:,-1]

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression().fit(X,Y)

# %%
print("Intercept:" , lr.intercept_)
print("Slope:",lr.coef_)
# Out:
# Intercept: 0.0
# Slope: [0.66666667]

# %%
reg_line=lr.coef_*X+lr.intercept_
plt.figure(figsize=(12,10))
plt.title("X vs Y",fontsize=20,color="Blue")
plt.scatter(X,Y,label="Model",color='red')
plt.plot(X,reg_line,label="Linear Regression",color="green")
